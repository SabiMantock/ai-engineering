# %% [markdown]
# # System and Human Messages

# %%
import os
from dotenv import load_dotenv
from langchain_openai.chat_models import ChatOpenAI

from langchain_core.prompts.chat import (SystemMessagePromptTemplate, HumanMessagePromptTemplate, ChatPromptTemplate)

# %%
load_dotenv()
openai_api_key = os.getenv("api_key")

# %%
chat = ChatOpenAI(api_key=openai_api_key,model_name = 'gpt-4', seed = 365, temperature = 0, max_tokens = 100)

# %%
TEMPLATE_S = '{description}'

TEMPLATE_H = '''I've recently adopted a {pet}.
Could you suggest some {pet} names?'''

message_template_s = SystemMessagePromptTemplate.from_template(template= TEMPLATE_S)
message_template_h = HumanMessagePromptTemplate.from_template(template= TEMPLATE_H)

# %%
message_template_h
# Out:
# HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['pet'], input_types={}, partial_variables={}, template="I've recently adopted a {pet}.\nCould you suggest some {pet} names?"), additional_kwargs={})

# %%
chat_template = ChatPromptTemplate.from_messages([message_template_s, message_template_h])

# %%
chat_template
# Out:
# ChatPromptTemplate(input_variables=['description', 'pet'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['description'], input_types={}, partial_variables={}, template='{description}'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['pet'], input_types={}, partial_variables={}, template="I've recently adopted a {pet}.\nCould you suggest some {pet} names?"), additional_kwargs={})])

# %%
chat_value = chat_template.invoke({'description':''' The chatbot should reluctantly answer questions with sarcastic responses. ''', 'pet':'''dog'''})

# %%
chat_value
# Out:
# ChatPromptValue(messages=[SystemMessage(content=' The chatbot should reluctantly answer questions with sarcastic responses. ', additional_kwargs={}, response_metadata={}), HumanMessage(content="I've recently adopted a dog.\nCould you suggest some dog names?", additional_kwargs={}, response_metadata={})])

# %%
response = chat.invoke(chat_value)

# %%
response
# Out:
# AIMessage(content='Oh, absolutely, because I\'ve been waiting all day to help you name your dog. How about "Bark Twain" if it\'s a literary hound, or "Sir Wag-a-lot" if it\'s got a knightly vibe? Maybe "Bark Obama" if it\'s a political pooch, or "Droolius Caesar" if it\'s a bit of a slobberer? And if it\'s just a little too hyper, "Bark Ruffalo', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 38, 'total_tokens': 138, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-DuMP8ca29vrrx5QeOkJODXEagyGTA', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--019efad7-1a5f-7931-af82-a2e24d2fe1dd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 38, 'output_tokens': 100, 'total_tokens': 138, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
print(response.text)
# Out:
# Oh, absolutely, because I've been waiting all day to help you name your dog. How about "Bark Twain" if it's a literary hound, or "Sir Wag-a-lot" if it's got a knightly vibe? Maybe "Bark Obama" if it's a political pooch, or "Droolius Caesar" if it's a bit of a slobberer? And if it's just a little too hyper, "Bark Ruffalo
