# %% [markdown]
# ### String Output Parser

# %%
import os
from dotenv import load_dotenv
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# %%
load_dotenv()
openai_api_key = os.getenv("api_key")

# %%
chat = ChatOpenAI(model_name="gpt-4o", seed=365, api_key=openai_api_key, temperature=0, max_tokens=100)

# %%
message_h = HumanMessage(content=f"' I've recently adopted a dog. Could you suggest some dog names? {CommaSeparatedListOutputParser().get_format_instructions()} '")

print(message_h.content)
# Out:
# ' I've recently adopted a dog. Could you suggest some dog names? Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz` '

# %%
response = chat.invoke([message_h])
print(response.content)
# Out:
# Buddy, Bella, Charlie, Luna, Max, Daisy, Rocky, Lucy, Cooper, Molly

# %%
list_output_parser = CommaSeparatedListOutputParser()

# %%
response_parsed = list_output_parser.invoke(response)

# %%
response_parsed
# Out:
# ['Congratulations on adopting a dog! Here are some name suggestions that might suit your new furry friend:',
#  '### Classic Names',
#  '1. Max',
#  '2. Bella',
#  '3. Charlie',
#  '4. Daisy',
#  '5. Buddy',
#  '6. Lucy',
#  '7. Rocky',
#  '8. Molly',
#  '9. Jack',
#  '10. Sadie',
#  '### Unique Names',
#  '1. Zephyr',
#  '2. Luna',
#  '3. Orion',
#  '4. Nova',
#  '5. Juno',
#  '6. Atlas',
#  '7. Ember',
#  '8.']

# %%
print(list_output_parser.get_format_instructions())
# Out:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`
